# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import kagglehub
# Out:
# /kaggle/input/datasets/jvkrishwanth/extracted/df_main_phase1.csv
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_27_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_14_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_3_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_22_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_15_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_16_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_23_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_19_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_7_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_12_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_25_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_14_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_11_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_18_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_16_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_22_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_8_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_2_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_28_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_25_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_19_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_7_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_20_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_1_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_24_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_22_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_15_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_28_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_8_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_24_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_13_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_18_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_10_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_13_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_20_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_24_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_5_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_20_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_16_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_1_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_26_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_25_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_17_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_23_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_10_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_9_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_11_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_8_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_18_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_12_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_15_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_17_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_5_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_17_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_3_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_26_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_9_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_13_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_27_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_26_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_5_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_9_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_2_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_2_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_19_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_23_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_3_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_7_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_10_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_1_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_12_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_28_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_14_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_11_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED/P_27_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_16_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_15_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_20_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_8_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_24_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_23_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_25_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_5_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_18_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_9_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_19_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_3_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_1_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_22_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_11_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_26_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_2_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_10_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_13_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_28_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_17_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_12_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_14_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_27_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset/P_7_MW-epo.fif

# %%
"""Kaggle-ready EEG band-power analysis for Focus versus Mind Wandering.

Outputs
-------
* One trajectory plot each for Delta, Theta, Alpha, Beta and Gamma.
* One combined trajectory plot (band-wise standardised log power).
* Tests of MW-vs-Focus mean power for every band.
* Tests of whether each band increases/decreases over time in
  Focus and in MW.

Attach the FIF files and the labels CSV in Kaggle, then edit FIF_DIR and
LABEL_CSV below. All outputs are written to /kaggle/working/all_band_results.
"""
from pathlib import Path
import warnings

import mne
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.signal import welch
from scipy.stats import norm
import statsmodels.formula.api as smf

FIF_DIR = Path("/kaggle/input/datasets/jvkrishwanth/extracted/extracted_dataset_ICA_CLEANED")
LABEL_CSV = Path("/kaggle/input/datasets/jvkrishwanth/extracted/df_main_phase1.csv")
FIF_TEMPLATE = "P_{subject}_MW-clean-epo.fif"
OUTPUT_DIR = Path("/kaggle/working/all_band_results")

BANDS = {
    "Delta": (1.0, 4.0), "Theta": (4.0, 8.0), "Alpha": (8.0, 12.0),
    "Beta": (13.0, 30.0), "Gamma": (30.0, 45.0),
}
# These work with short epochs. Overlap is used only to estimate each epoch's
# slope; statistical tests use one summary/slope per epoch, not every window.
WINDOW_SECONDS, STEP_SECONDS = 1.0, 0.5
CHANNELS = ["FP1", "FP2", "F7", "F3", "FZ", "F4", "F8", "T3", "C3", "CZ", "C4",
            "T4", "T5", "P3", "PZ", "P4", "T6", "O1", "O2"]
MW_EPOCH_TMIN = -5.0
FOCUS_START_OFFSET = 1.0  # Epochs span tmin=-5.0 to tmax=-0.1 relative to button press


def normalise_state(values):
    value = values.astype("string").str.strip().str.upper()
    result = pd.Series(np.where(value.isin({"MW", "MIND WANDERING", "MIND_WANDERING", "1"}),
                                "MW", "Focus"), index=values.index, dtype="string")
    result.loc[value.isna() | value.eq("")] = pd.NA
    return result


def labels_for_subject(labels, subject, n_epochs):
    required = {"Subject", "State"}
    if not required.issubset(labels.columns):
        raise ValueError(f"LABEL_CSV must include {required}; found {list(labels.columns)}")
    sub = labels.loc[labels["Subject"].astype(str) == str(subject)].copy()
    order = [c for c in ["Session", "Epoch_Index"] if c in sub.columns]
    if order:
        sub = sub.sort_values(order).groupby(order, as_index=False)["State"].first()
    state = normalise_state(sub["State"]).to_numpy()
    if len(state) != n_epochs:
        warnings.warn(f"Skipping subject {subject}: {len(state)} labels versus {n_epochs} EEG epochs.")
        return np.array([])
    return state


def extract_windows(labels):
    rows = []
    for fif_path in sorted(FIF_DIR.glob("P_*_MW*-epo.fif")):
        subject = fif_path.name.split("_")[1]
        expected = FIF_DIR / FIF_TEMPLATE.format(subject=subject)
        if expected.exists() and fif_path != expected:
            continue
        print(f"Reading {fif_path.name}")
        epochs = mne.read_epochs(fif_path, preload=True, verbose=False)
        available = [c for c in CHANNELS if c in epochs.ch_names]
        if not available:
            continue
        epochs.pick(available)
        state = ["MW" if event[2] == 1 else "Focus" for event in epochs.events]
        if not len(state):
            continue
        sfreq = epochs.info["sfreq"]
        window_n, step_n = round(WINDOW_SECONDS * sfreq), round(STEP_SECONDS * sfreq)
        for epoch_index, (epoch, epoch_state) in enumerate(zip(epochs.get_data(copy=True), state)):
            if pd.isna(epoch_state):
                continue
            for window_index, start in enumerate(range(0, epoch.shape[-1] - window_n + 1, step_n)):
                if epoch_state == "MW" and start + window_n > round(4.9 * sfreq):
                    continue
                segment = epoch[:, start:start + window_n]
                freqs, psd = welch(segment, fs=sfreq, nperseg=window_n, axis=-1)
                row = {"Subject": str(subject), "Epoch": f"{subject}_{epoch_index}", "State": epoch_state,
                       "Epoch_Index": epoch_index, "Window_Index": window_index,
                       "Time_s": (start + window_n / 2) / sfreq}
                for band, (low, high) in BANDS.items():
                    mask = (freqs >= low) & (freqs < high)
                    if mask.any():
                        row[f"Log10_{band}_Power"] = np.log10(psd[:, mask].mean() + 1e-20)
                rows.append(row)
    df = pd.DataFrame(rows)
    if df.empty:
        raise RuntimeError("No windows extracted. Check FIF_DIR, FIF_TEMPLATE, channel names, and labels.")
    return df


def epoch_summaries(windows, band):
    power_col = f"Log10_{band}_Power"
    rows = []
    for (subject, epoch, state), part in windows.groupby(["Subject", "Epoch", "State"], observed=True):
        part = part.dropna(subset=["Time_s", power_col])
        if part.empty:
            continue
        row = {"Subject": subject, "Epoch": epoch, "State": state,
               "Mean_log10_power": part[power_col].mean(), "N_Windows": len(part)}
        if len(part) >= 3 and part["Time_s"].nunique() >= 2:
            row["Slope_log10_power_per_second"] = np.polyfit(part["Time_s"], part[power_col], 1)[0]
        else:
            row["Slope_log10_power_per_second"] = np.nan
        rows.append(row)
    return pd.DataFrame(rows)


def contrast_result(fit, contrast, label, effect, alternative="two-sided"):
    params, cov = fit.params, fit.cov_params().loc[fit.params.index, fit.params.index]
    estimate = float(contrast @ params.to_numpy())
    se = float(np.sqrt(contrast @ cov.to_numpy() @ contrast))
    z = estimate / se
    p = 2 * norm.sf(abs(z)) if alternative == "two-sided" else (norm.sf(z) if alternative == ">" else norm.cdf(z))
    return {"Band": label, "Analysis": effect, "Estimate": estimate, "SE": se, "z": z,
            "CI_95_low": estimate - 1.96 * se, "CI_95_high": estimate + 1.96 * se,
            "p_value": p}


def analyse_band(windows, band):
    summary = epoch_summaries(windows, band)
    summary["State"] = pd.Categorical(summary["State"], categories=["Focus", "MW"])
    if not {"Focus", "MW"}.issubset(set(summary["State"].dropna())):
        raise ValueError(f"{band}: both Focus and MW epochs are required.")

    # MW - Focus mean epoch power. Clustered SEs account for repeated epochs per participant.
    mean_fit = smf.ols("Mean_log10_power ~ C(State, Treatment(reference='Focus'))", summary).fit(
        cov_type="cluster", cov_kwds={"groups": summary["Subject"]})
    mean_names = list(mean_fit.params.index)
    state_term = next(n for n in mean_names if n.startswith("C(State,"))
    mean_contrast = np.zeros(len(mean_names)); mean_contrast[mean_names.index(state_term)] = 1
    results = [contrast_result(mean_fit, mean_contrast, band, "MW minus Focus mean power")]

    # State-specific epoch slopes. A two-sided p value tests change in either direction;
    # the estimate's sign reports whether that change is increase or decrease.
    trend = summary.dropna(subset=["Slope_log10_power_per_second"]).copy()
    trend_fit = smf.ols("Slope_log10_power_per_second ~ C(State, Treatment(reference='Focus'))", trend).fit(
        cov_type="cluster", cov_kwds={"groups": trend["Subject"]})
    names = list(trend_fit.params.index)
    state_term = next(n for n in names if n.startswith("C(State,"))
    focus = np.zeros(len(names)); focus[names.index("Intercept")] = 1
    mw = focus.copy(); mw[names.index(state_term)] = 1
    results.extend([
        contrast_result(trend_fit, focus, band, "Focus change over time"),
        contrast_result(trend_fit, mw, band, "MW change over time"),
    ])
    return summary, results


def add_statistical_decisions(results):
    """Annotate each test at alpha = 0.05."""
    results = results.copy()
    decisions = []
    for _, row in results.iterrows():
        if row["p_value"] >= 0.05:
            decisions.append("Not statistically significant")
        elif row["Analysis"] == "MW minus Focus mean power":
            decisions.append("MW higher power" if row["Estimate"] > 0 else "MW lower power")
        else:
            decisions.append("Increases over time" if row["Estimate"] > 0 else "Decreases over time")
    results["Statistical_decision_alpha_0.05"] = decisions
    return results

def plot_band(windows, band):
    value = f"Log10_{band}_Power"
    subj = windows.groupby(["Subject", "State", "Time_s"], as_index=False)[value].mean()
    stats = subj.groupby(["State", "Time_s"], as_index=False)[value].agg(mean="mean", sem="sem")
    fig, ax = plt.subplots(figsize=(9, 5.5))
    for state, colour in [("Focus", "#2878B5"), ("MW", "#D1495B")]:
        s = stats[stats.State == state]
        plot_time = s.Time_s + MW_EPOCH_TMIN
        ax.plot(plot_time, s["mean"], marker="o", lw=2.5, label=state, color=colour)
        ax.fill_between(plot_time, s["mean"] - s["sem"], s["mean"] + s["sem"], color=colour, alpha=.2)
    ax.set(title=f"{band}-band power over time", xlabel="Time (s)",
           ylabel=f"Mean log10 {band.lower()} PSD (power/Hz)")
    ax.legend(title="State", loc="upper right"); fig.tight_layout()
    fig.savefig(OUTPUT_DIR / f"{band.lower()}_band_power_over_time.png", dpi=200)
    plt.close(fig)
    return subj


def plot_all_bands(subject_curves):
    # Standardisation is solely for a readable common y-axis; use individual plots
    # and CSV estimates for physical log-power values.
    fig, axes = plt.subplots(1, 2, figsize=(15, 5.5), sharey=True)
    colours = {"Delta": "#4C78A8", "Theta": "#F58518", "Alpha": "#54A24B", "Beta": "#E45756", "Gamma": "#B279A2"}
    for ax, state in zip(axes, ["Focus", "MW"]):
        for band, curve in subject_curves.items():
            value = f"Log10_{band}_Power"
            part = curve[curve.State == state].copy()
            z = (part[value] - subject_curves[band][value].mean()) / subject_curves[band][value].std(ddof=0)
            summary = pd.DataFrame({"Time_s": part.Time_s, "z": z}).groupby("Time_s").z.agg(["mean", "sem"]).reset_index()
            plot_time = summary.Time_s + MW_EPOCH_TMIN
            ax.plot(plot_time, summary["mean"], marker="o", lw=2, label=band, color=colours[band])
            ax.fill_between(plot_time, summary["mean"]-summary["sem"], summary["mean"]+summary["sem"], color=colours[band], alpha=.12)
        ax.axhline(0, color="black", lw=.8); ax.set(title=state, xlabel="Time relative to bell (s)")
    axes[0].set_ylabel("Standardised mean log10 PSD (z)")
    axes[1].legend(title="Band", bbox_to_anchor=(1.02, 1), loc="upper left")
    fig.suptitle("All EEG bands: power trajectories", y=1.02); fig.tight_layout()
    fig.savefig(OUTPUT_DIR / "all_bands_power_over_time_standardised.png", dpi=200, bbox_inches="tight")
    plt.close(fig)


def main():
    OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
    sns.set_theme(style="whitegrid", context="talk")
    windows = extract_windows(pd.read_csv(LABEL_CSV))
    windows.to_csv(OUTPUT_DIR / "all_band_window_level_data.csv", index=False)
    all_results, curves = [], {}
    for band in BANDS:
        summary, band_results = analyse_band(windows, band)
        summary.to_csv(OUTPUT_DIR / f"{band.lower()}_epoch_summaries.csv", index=False)
        all_results.extend(band_results)
        curves[band] = plot_band(windows, band)
    results = add_statistical_decisions(pd.DataFrame(all_results))
    results.to_csv(OUTPUT_DIR / "all_band_statistical_results.csv", index=False)
    plot_all_bands(curves)
    print("\nStatistical results:\n", results.to_string(index=False))
    significant_results = results.loc[results["p_value"] < 0.05].sort_values("p_value").copy()
    print("\nAll statistically significant results (p < 0.05):\n", significant_results.to_string(index=False))
    remaining_results = results.loc[results["p_value"] >= 0.05].nsmallest(5, "p_value")
    print("\nFive lowest p-value results among the remaining analyses:\n", remaining_results.to_string(index=False))    
    print(f"\nSaved plots and CSV files to {OUTPUT_DIR}")


if __name__ == "__main__":
    main()
# Out:
# Reading P_10_MW-clean-epo.fif
# Reading P_11_MW-clean-epo.fif
# Reading P_12_MW-clean-epo.fif
# Reading P_13_MW-clean-epo.fif
# Reading P_14_MW-clean-epo.fif
# Reading P_15_MW-clean-epo.fif
# Reading P_16_MW-clean-epo.fif
# Reading P_17_MW-clean-epo.fif
# Reading P_18_MW-clean-epo.fif
# Reading P_19_MW-clean-epo.fif
# Reading P_1_MW-clean-epo.fif
# Reading P_20_MW-clean-epo.fif
# Reading P_22_MW-clean-epo.fif
# Reading P_23_MW-clean-epo.fif
# Reading P_24_MW-clean-epo.fif
# Reading P_25_MW-clean-epo.fif
# Reading P_26_MW-clean-epo.fif
# Reading P_27_MW-clean-epo.fif
# Reading P_28_MW-clean-epo.fif
# Reading P_2_MW-clean-epo.fif
# Reading P_3_MW-clean-epo.fif
# Reading P_5_MW-clean-epo.fif
# Reading P_7_MW-clean-epo.fif
# Reading P_8_MW-clean-epo.fif
# Reading P_9_MW-clean-epo.fif
#
# Statistical results:
#   Band                  Analysis  Estimate       SE         z  CI_95_low  CI_95_high  p_value Statistical_decision_alpha_0.05
# Delta MW minus Focus mean power  0.094793 0.055934  1.694735  -0.014837    0.204423 0.090126   Not statistically significant
# Delta    Focus change over time -0.002191 0.003670 -0.596955  -0.009384    0.005002 0.550537   Not statistically significant
# Delta       MW change over time  0.005278 0.005219  1.011353  -0.004951    0.015507 0.311848   Not statistically significant
# Theta MW minus Focus mean power  0.081590 0.060511  1.348353  -0.037011    0.200191 0.177545   Not statistically significant
# Theta    Focus change over time -0.002335 0.003214 -0.726594  -0.008634    0.003964 0.467474   Not statistically significant
# Theta       MW change over time  0.005420 0.004631  1.170410  -0.003657    0.014497 0.241836   Not statistically significant
# Alpha MW minus Focus mean power -0.111281 0.086497 -1.286533  -0.280815    0.058253 0.198257   Not statistically significant
# Alpha    Focus change over time -0.003239 0.004201 -0.770990  -0.011474    0.004995 0.440713   Not statistically significant
# Alpha       MW change over time  0.005890 0.007722  0.762747  -0.009245    0.021024 0.445614   Not statistically significant
#  Beta MW minus Focus mean power -0.049420 0.064630 -0.764657  -0.176096    0.077255 0.444476   Not statistically significant
#  Beta    Focus change over time -0.000007 0.001922 -0.003466  -0.003775    0.003761 0.997235   Not statistically significant
#  Beta       MW change over time -0.003720 0.003601 -1.033030  -0.010778    0.003338 0.301590   Not statistically significant
# Gamma MW minus Focus mean power -0.032202 0.074110 -0.434513  -0.177456    0.113053 0.663916   Not statistically significant
# Gamma    Focus change over time -0.000722 0.001731 -0.417416  -0.004115    0.002670 0.676374   Not statistically significant
# Gamma       MW change over time  0.000817 0.001862  0.438650  -0.002833    0.004466 0.660915   Not statistically significant
#
# All statistically significant results (p < 0.05):
#  Empty DataFrame
# Columns: [Band, Analysis, Estimate, SE, z, CI_95_low, CI_95_high, p_value, Statistical_decision_alpha_0.05]
# Index: []
#
# Five lowest p-value results among the remaining analyses:
#   Band                  Analysis  Estimate       SE         z  CI_95_low  CI_95_high  p_value Statistical_decision_alpha_0.05
# Delta MW minus Focus mean power  0.094793 0.055934  1.694735  -0.014837    0.204423 0.090126   Not statistically significant
# Theta MW minus Focus mean power  0.081590 0.060511  1.348353  -0.037011    0.200191 0.177545   Not statistically significant
# Alpha MW minus Focus mean power -0.111281 0.086497 -1.286533  -0.280815    0.058253 0.198257   Not statistically significant
# Theta       MW change over time  0.005420 0.004631  1.170410  -0.003657    0.014497 0.241836   Not statistically significant
#  Beta       MW change over time -0.003720 0.003601 -1.033030  -0.010778    0.003338 0.301590   Not statistically significant
#
# Saved plots and CSV files to /kaggle/working/all_band_results
