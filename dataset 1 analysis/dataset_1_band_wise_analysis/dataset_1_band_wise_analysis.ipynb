# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Manuscript accepted in the European Journal of Neuroscience.pdf
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/readme.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/MATLAB scripts/findpeaks_analysis_1fthreshold.m
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/MATLAB scripts/estimate_1f.m
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/MATLAB scripts/convertDatatoFieldtrip3.m
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/MATLAB scripts/get_behavioral_data.m
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/MATLAB scripts/read_preprocess_and_epoch_EEG.m
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/MATLAB scripts/IF_and_PLV.m
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/MATLAB scripts/read_preprocess_and_epoch_EOG.m
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/MATLAB scripts/amplitude_analysis.m
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/MATLAB scripts/findpeaks_analysis_nothreshold.m
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/MATLAB scripts/reject_components.m
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/MATLAB scripts/IF_and_PLV_withfindpeaks.m
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/MATLAB scripts/permutation stats/exploratory_condition.m
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/MATLAB scripts/permutation stats/chanlocs.mat
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/MATLAB scripts/permutation stats/electrode19.mat
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_19_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_15_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_8_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_20_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_2_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_27_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_26_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_10_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_24_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_13_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_1_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_7_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_11_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_9_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_14_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_23_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_18_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_22_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_28_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_3_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_17_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_12_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_5_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_16_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EEG/P_25_MW.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P2.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P25.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P22.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P9.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P28.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P16.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P8.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P18.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P5.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P1.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P13.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P10.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P7.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P14.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P11.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P27.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P3.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P12.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P23.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P19.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P15.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P26.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P17.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P20.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Raw data/EOG/MW_P24.txt
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Other files/debriefings.xlsx
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Other files/robust_estimation_1f_per_electrodeandsubject_excl_alpha.mat
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Other files/weights_per_epoch_after_rejection.mat
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Other files/EEG21locs.mat
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Other files/eprime task files/mind_wandering_experiment.es2
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Other files/eprime task files/mind_wandering_experiment.wndpos
# /kaggle/input/datasets/jvkrishwanth/mw-dataset1/Other files/eprime task files/mind_wandering_experiment.ebs2
# /kaggle/input/datasets/jvkrishwanth/extracted/P_16_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_15_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_20_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_8_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_24_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_23_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_25_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_5_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_18_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_9_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_19_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_3_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_1_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_22_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_11_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_26_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_2_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_10_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_13_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_28_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_17_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_12_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_14_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_27_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/extracted/P_7_MW-epo.fif
# /kaggle/input/datasets/jvkrishwanth/df-main-phase1/df_main_phase1.csv
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_27_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_14_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_3_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_22_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_15_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_16_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_23_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_19_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_7_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_12_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_25_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_14_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_11_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_18_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_16_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_22_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_8_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_2_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_28_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_25_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_19_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_7_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_20_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_1_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_24_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_22_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_15_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_28_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_8_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_24_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_13_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_18_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_10_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_13_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_20_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_24_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_5_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_20_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_16_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_1_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_26_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_25_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_17_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_23_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_10_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_9_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_11_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_8_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_18_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_12_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_15_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_17_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_5_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_17_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_3_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_26_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_9_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_13_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_27_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_26_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_5_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_9_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_2_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_2_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_19_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_23_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_3_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_7_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_10_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_1_MW-ica-metadata.mat
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_12_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_28_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_14_MW-ica.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_11_MW-clean-epo.fif
# /kaggle/input/datasets/jvkrishwanth/ica-cleaned/P_27_MW-ica-metadata.mat

# %%
"""Kaggle-ready EEG band-power analysis for Focus versus Mind Wandering.

Outputs
-------
* One trajectory plot each for Delta, Theta, Alpha, Beta and Gamma.
* One combined trajectory plot (band-wise standardised log power).
* Tests of MW-vs-Focus mean power for every band.
* Tests of whether each band increases/decreases over time in
  Focus and in MW.

Attach the FIF files and the labels CSV in Kaggle, then edit FIF_DIR and
LABEL_CSV below. All outputs are written to /kaggle/working/all_band_results.
"""
from pathlib import Path
import warnings

import mne
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.signal import welch
from scipy.stats import norm
import statsmodels.formula.api as smf

# --- Edit these paths to the names of your Kaggle input datasets. ---
FIF_DIR = Path("/kaggle/input/datasets/jvkrishwanth/ica-cleaned")
LABEL_CSV = Path("/kaggle/input/datasets/jvkrishwanth/df-main-phase1/df_main_phase1.csv")
FIF_TEMPLATE = "P_{subject}_MW-clean-epo.fif"
OUTPUT_DIR = Path("/kaggle/working/all_band_results")

BANDS = {
    "Delta": (1.0, 4.0), "Theta": (4.0, 8.0), "Alpha": (8.0, 12.0),
    "Beta": (13.0, 30.0), "Gamma": (30.0, 45.0),
}
# These work with short epochs. Overlap is used only to estimate each epoch's
# slope; statistical tests use one summary/slope per epoch, not every window.
WINDOW_SECONDS, STEP_SECONDS = 1.0, 0.5
CHANNELS = ["FP1", "FP2", "F7", "F3", "FZ", "F4", "F8", "T3", "C3", "CZ", "C4",
            "T4", "T5", "P3", "PZ", "P4", "T6", "O1", "O2"]
MW_EPOCH_TMIN = -5.0  # Epochs span tmin=-5.0 to tmax=-0.1 relative to button press


def normalise_state(values):
    value = values.astype("string").str.strip().str.upper()
    result = pd.Series(np.where(value.isin({"MW", "MIND WANDERING", "MIND_WANDERING", "1"}),
                                "MW", "Focus"), index=values.index, dtype="string")
    result.loc[value.isna() | value.eq("")] = pd.NA
    return result


def labels_for_subject(labels, subject, n_epochs):
    required = {"Subject", "State"}
    if not required.issubset(labels.columns):
        raise ValueError(f"LABEL_CSV must include {required}; found {list(labels.columns)}")
    sub = labels.loc[labels["Subject"].astype(str) == str(subject)].copy()
    order = [c for c in ["Session", "Epoch_Index"] if c in sub.columns]
    if order:
        sub = sub.sort_values(order).groupby(order, as_index=False)["State"].first()
    state = normalise_state(sub["State"]).to_numpy()
    if len(state) != n_epochs:
        warnings.warn(f"Skipping subject {subject}: {len(state)} labels versus {n_epochs} EEG epochs.")
        return np.array([])
    return state


def extract_windows(labels):
    rows = []
    for fif_path in sorted(FIF_DIR.glob("P_*_MW*-epo.fif")):
        subject = fif_path.name.split("_")[1]
        expected = FIF_DIR / FIF_TEMPLATE.format(subject=subject)
        if expected.exists() and fif_path != expected:
            continue
        print(f"Reading {fif_path.name}")
        epochs = mne.read_epochs(fif_path, preload=True, verbose=False)
        available = [c for c in CHANNELS if c in epochs.ch_names]
        if not available:
            continue
        epochs.pick(available)
        state = labels_for_subject(labels, subject, len(epochs))
        if not len(state):
            continue
        sfreq = epochs.info["sfreq"]
        window_n, step_n = round(WINDOW_SECONDS * sfreq), round(STEP_SECONDS * sfreq)
        for epoch_index, (epoch, epoch_state) in enumerate(zip(epochs.get_data(copy=True), state)):
            if pd.isna(epoch_state):
                continue
            for window_index, start in enumerate(range(0, epoch.shape[-1] - window_n + 1, step_n)):
                segment = epoch[:, start:start + window_n]
                freqs, psd = welch(segment, fs=sfreq, nperseg=window_n, axis=-1)
                row = {"Subject": str(subject), "Epoch": f"{subject}_{epoch_index}", "State": epoch_state,
                       "Epoch_Index": epoch_index, "Window_Index": window_index,
                       "Time_s": (start + window_n / 2) / sfreq}
                for band, (low, high) in BANDS.items():
                    mask = (freqs >= low) & (freqs < high)
                    if mask.any():
                        row[f"Log10_{band}_Power"] = np.log10(psd[:, mask].mean() + 1e-20)
                rows.append(row)
    df = pd.DataFrame(rows)
    if df.empty:
        raise RuntimeError("No windows extracted. Check FIF_DIR, FIF_TEMPLATE, channel names, and labels.")
    return df


def epoch_summaries(windows, band):
    power_col = f"Log10_{band}_Power"
    rows = []
    for (subject, epoch, state), part in windows.groupby(["Subject", "Epoch", "State"], observed=True):
        part = part.dropna(subset=["Time_s", power_col])
        if part.empty:
            continue
        row = {"Subject": subject, "Epoch": epoch, "State": state,
               "Mean_log10_power": part[power_col].mean(), "N_Windows": len(part)}
        if len(part) >= 3 and part["Time_s"].nunique() >= 2:
            row["Slope_log10_power_per_second"] = np.polyfit(part["Time_s"], part[power_col], 1)[0]
        else:
            row["Slope_log10_power_per_second"] = np.nan
        rows.append(row)
    return pd.DataFrame(rows)


def contrast_result(fit, contrast, label, effect, alternative="two-sided"):
    params, cov = fit.params, fit.cov_params().loc[fit.params.index, fit.params.index]
    estimate = float(contrast @ params.to_numpy())
    se = float(np.sqrt(contrast @ cov.to_numpy() @ contrast))
    z = estimate / se
    p = 2 * norm.sf(abs(z)) if alternative == "two-sided" else (norm.sf(z) if alternative == ">" else norm.cdf(z))
    return {"Band": label, "Analysis": effect, "Estimate": estimate, "SE": se, "z": z,
            "CI_95_low": estimate - 1.96 * se, "CI_95_high": estimate + 1.96 * se,
            "p_value": p}


def analyse_band(windows, band):
    summary = epoch_summaries(windows, band)
    summary["State"] = pd.Categorical(summary["State"], categories=["Focus", "MW"])
    if not {"Focus", "MW"}.issubset(set(summary["State"].dropna())):
        raise ValueError(f"{band}: both Focus and MW epochs are required.")

    # MW - Focus mean epoch power. Clustered SEs account for repeated epochs per participant.
    mean_fit = smf.ols("Mean_log10_power ~ C(State, Treatment(reference='Focus'))", summary).fit(
        cov_type="cluster", cov_kwds={"groups": summary["Subject"]})
    mean_names = list(mean_fit.params.index)
    state_term = next(n for n in mean_names if n.startswith("C(State,"))
    mean_contrast = np.zeros(len(mean_names)); mean_contrast[mean_names.index(state_term)] = 1
    results = [contrast_result(mean_fit, mean_contrast, band, "MW minus Focus mean power")]

    # State-specific epoch slopes. A two-sided p value tests change in either direction;
    # the estimate's sign reports whether that change is increase or decrease.
    trend = summary.dropna(subset=["Slope_log10_power_per_second"]).copy()
    trend_fit = smf.ols("Slope_log10_power_per_second ~ C(State, Treatment(reference='Focus'))", trend).fit(
        cov_type="cluster", cov_kwds={"groups": trend["Subject"]})
    names = list(trend_fit.params.index)
    state_term = next(n for n in names if n.startswith("C(State,"))
    focus = np.zeros(len(names)); focus[names.index("Intercept")] = 1
    mw = focus.copy(); mw[names.index(state_term)] = 1
    results.extend([
        contrast_result(trend_fit, focus, band, "Focus change over time"),
        contrast_result(trend_fit, mw, band, "MW change over time"),
    ])
    return summary, results


def add_statistical_decisions(results):
    """Annotate each test at alpha = 0.05."""
    results = results.copy()
    decisions = []
    for _, row in results.iterrows():
        if row["p_value"] >= 0.05:
            decisions.append("Not statistically significant")
        elif row["Analysis"] == "MW minus Focus mean power":
            decisions.append("MW higher power" if row["Estimate"] > 0 else "MW lower power")
        else:
            decisions.append("Increases over time" if row["Estimate"] > 0 else "Decreases over time")
    results["Statistical_decision_alpha_0.05"] = decisions
    return results

def plot_band(windows, band):
    value = f"Log10_{band}_Power"
    subj = windows.groupby(["Subject", "State", "Time_s"], as_index=False)[value].mean()
    stats = subj.groupby(["State", "Time_s"], as_index=False)[value].agg(mean="mean", sem="sem")
    fig, ax = plt.subplots(figsize=(9, 5.5))
    for state, colour in [("Focus", "#2878B5"), ("MW", "#D1495B")]:
        s = stats[stats.State == state]
        plot_time = s.Time_s + MW_EPOCH_TMIN if state == "MW" else s.Time_s
        ax.plot(plot_time, s["mean"], marker="o", lw=2.5, label=state, color=colour)
        ax.fill_between(plot_time, s["mean"] - s["sem"], s["mean"] + s["sem"], color=colour, alpha=.2)
    ax.set(title=f"{band}-band power over time", xlabel="Time (s)",
           ylabel=f"Mean log10 {band.lower()} PSD (power/Hz)")
    ax.legend(title="State"); fig.tight_layout()
    fig.savefig(OUTPUT_DIR / f"{band.lower()}_band_power_over_time.png", dpi=200)
    plt.close(fig)
    return subj


def plot_all_bands(subject_curves):
    # Standardisation is solely for a readable common y-axis; use individual plots
    # and CSV estimates for physical log-power values.
    fig, axes = plt.subplots(1, 2, figsize=(15, 5.5), sharey=True)
    colours = {"Delta": "#4C78A8", "Theta": "#F58518", "Alpha": "#54A24B", "Beta": "#E45756", "Gamma": "#B279A2"}
    for ax, state in zip(axes, ["Focus", "MW"]):
        for band, curve in subject_curves.items():
            value = f"Log10_{band}_Power"
            part = curve[curve.State == state].copy()
            z = (part[value] - subject_curves[band][value].mean()) / subject_curves[band][value].std(ddof=0)
            summary = pd.DataFrame({"Time_s": part.Time_s, "z": z}).groupby("Time_s").z.agg(["mean", "sem"]).reset_index()
            plot_time = summary.Time_s + MW_EPOCH_TMIN if state == "MW" else summary.Time_s
            ax.plot(plot_time, summary["mean"], marker="o", lw=2, label=band, color=colours[band])
            ax.fill_between(plot_time, summary["mean"]-summary["sem"], summary["mean"]+summary["sem"], color=colours[band], alpha=.12)
        ax.axhline(0, color="black", lw=.8); ax.set(title=state, xlabel="Time relative to button press (s)" if state == "MW" else "Time within epoch (s)")
    axes[0].set_ylabel("Standardised mean log10 PSD (z)")
    axes[1].legend(title="Band", bbox_to_anchor=(1.02, 1), loc="upper left")
    fig.suptitle("All EEG bands: power trajectories", y=1.02); fig.tight_layout()
    fig.savefig(OUTPUT_DIR / "all_bands_power_over_time_standardised.png", dpi=200, bbox_inches="tight")
    plt.close(fig)


def main():
    OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
    sns.set_theme(style="whitegrid", context="talk")
    windows = extract_windows(pd.read_csv(LABEL_CSV))
    windows.to_csv(OUTPUT_DIR / "all_band_window_level_data.csv", index=False)
    all_results, curves = [], {}
    for band in BANDS:
        summary, band_results = analyse_band(windows, band)
        summary.to_csv(OUTPUT_DIR / f"{band.lower()}_epoch_summaries.csv", index=False)
        all_results.extend(band_results)
        curves[band] = plot_band(windows, band)
    results = add_statistical_decisions(pd.DataFrame(all_results))
    results.to_csv(OUTPUT_DIR / "all_band_statistical_results.csv", index=False)
    plot_all_bands(curves)
    print("\nStatistical results:\n", results.to_string(index=False))
    significant_results = results.loc[results["p_value"] < 0.05].sort_values("p_value").copy()
    print("\nAll statistically significant results (p < 0.05):\n", significant_results.to_string(index=False))
    remaining_results = results.loc[results["p_value"] >= 0.05].nsmallest(5, "p_value")
    print("\nFive lowest p-value results among the remaining analyses:\n", remaining_results.to_string(index=False))    
    print(f"\nSaved plots and CSV files to {OUTPUT_DIR}")


if __name__ == "__main__":
    main()
# Out:
# Reading P_10_MW-clean-epo.fif
# Reading P_11_MW-clean-epo.fif
# Reading P_12_MW-clean-epo.fif
# Reading P_13_MW-clean-epo.fif
# Reading P_14_MW-clean-epo.fif
# Reading P_15_MW-clean-epo.fif
# Reading P_16_MW-clean-epo.fif
# Reading P_17_MW-clean-epo.fif
# Reading P_18_MW-clean-epo.fif
# Reading P_19_MW-clean-epo.fif
# Reading P_1_MW-clean-epo.fif
# Reading P_20_MW-clean-epo.fif
# Reading P_22_MW-clean-epo.fif
# Reading P_23_MW-clean-epo.fif
# Reading P_24_MW-clean-epo.fif
# Reading P_25_MW-clean-epo.fif
# Reading P_26_MW-clean-epo.fif
# Reading P_27_MW-clean-epo.fif
# Reading P_28_MW-clean-epo.fif
# Reading P_2_MW-clean-epo.fif
# Reading P_3_MW-clean-epo.fif
# Reading P_5_MW-clean-epo.fif
# Reading P_7_MW-clean-epo.fif
# Reading P_8_MW-clean-epo.fif
# Reading P_9_MW-clean-epo.fif
#
# Statistical results:
#   Band                  Analysis  Estimate       SE         z  CI_95_low  CI_95_high  p_value Statistical_decision_alpha_0.05
# Delta MW minus Focus mean power  0.029181 0.031442  0.928067  -0.032447    0.090808 0.353373   Not statistically significant
# Delta    Focus change over time -0.000442 0.002991 -0.147834  -0.006304    0.005420 0.882474   Not statistically significant
# Delta       MW change over time  0.001254 0.005129  0.244508  -0.008798    0.011307 0.806837   Not statistically significant
# Theta MW minus Focus mean power  0.023489 0.035213  0.667046  -0.045529    0.092506 0.504743   Not statistically significant
# Theta    Focus change over time -0.003935 0.003272 -1.202821  -0.010348    0.002477 0.229045   Not statistically significant
# Theta       MW change over time  0.008018 0.003513  2.282256   0.001132    0.014903 0.022474             Increases over time
# Alpha MW minus Focus mean power -0.148491 0.077332 -1.920177  -0.300063    0.003080 0.054836   Not statistically significant
# Alpha    Focus change over time -0.006318 0.004799 -1.316574  -0.015725    0.003088 0.187982   Not statistically significant
# Alpha       MW change over time  0.003986 0.007970  0.500154  -0.011635    0.019608 0.616966   Not statistically significant
#  Beta MW minus Focus mean power -0.105975 0.046638 -2.272285  -0.197386   -0.014564 0.023069                  MW lower power
#  Beta    Focus change over time -0.000713 0.001981 -0.359963  -0.004595    0.003169 0.718875   Not statistically significant
#  Beta       MW change over time -0.003923 0.003662 -1.071413  -0.011100    0.003254 0.283984   Not statistically significant
# Gamma MW minus Focus mean power -0.082474 0.052976 -1.556821  -0.186307    0.021359 0.119513   Not statistically significant
# Gamma    Focus change over time -0.001320 0.001622 -0.813695  -0.004499    0.001860 0.415820   Not statistically significant
# Gamma       MW change over time -0.000446 0.002074 -0.215152  -0.004512    0.003620 0.829649   Not statistically significant
#
# All statistically significant results (p < 0.05):
#   Band                  Analysis  Estimate       SE         z  CI_95_low  CI_95_high  p_value Statistical_decision_alpha_0.05
# Theta       MW change over time  0.008018 0.003513  2.282256   0.001132    0.014903 0.022474             Increases over time
#  Beta MW minus Focus mean power -0.105975 0.046638 -2.272285  -0.197386   -0.014564 0.023069                  MW lower power
#
# Five lowest p-value results among the remaining analyses:
#   Band                  Analysis  Estimate       SE         z  CI_95_low  CI_95_high  p_value Statistical_decision_alpha_0.05
# Alpha MW minus Focus mean power -0.148491 0.077332 -1.920177  -0.300063    0.003080 0.054836   Not statistically significant
# Gamma MW minus Focus mean power -0.082474 0.052976 -1.556821  -0.186307    0.021359 0.119513   Not statistically significant
# Alpha    Focus change over time -0.006318 0.004799 -1.316574  -0.015725    0.003088 0.187982   Not statistically significant
# Theta    Focus change over time -0.003935 0.003272 -1.202821  -0.010348    0.002477 0.229045   Not statistically significant
#  Beta       MW change over time -0.003923 0.003662 -1.071413  -0.011100    0.003254 0.283984   Not statistically significant
#
# Saved plots and CSV files to /kaggle/working/all_band_results
