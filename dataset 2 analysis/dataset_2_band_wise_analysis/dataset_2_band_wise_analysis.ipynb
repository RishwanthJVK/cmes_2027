# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/sub-02_sessions.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/sub-02_events.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-7_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-8_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-5_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-10_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-8_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-4_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-6_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-1_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-9_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-5_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-11_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-9_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-7_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-10_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-10_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-8_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-3_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-11_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-10_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-1_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-9_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-6_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-4_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-3_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-2_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-8_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-5_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-5_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-3_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-6_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-1_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-11_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-2_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-4_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-2_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-9_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-4_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/eeg/sub-02_ses-7_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-001/sub-02/anat/sub-02_T1.nii
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/sub-01_sessions.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/sub-01_events.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-6_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-9_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-4_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-6_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-10_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-1_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-1_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-8_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-8_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-7_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-2_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-8_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-7_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-2_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-3_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-11_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-6_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-6_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-1_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-3_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-9_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-10_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-11_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-7_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-9_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-4_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-4_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-9_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-7_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-2_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-5_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-11_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-5_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-5_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-3_task-BreathCounting_channels.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-8_task-BreathCounting_electrodes.tsv
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/eeg/sub-01_ses-10_task-BreathCounting_eeg.json
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-001/sub-01/anat/sub-01_T1.nii
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-002/sub-01/eeg/sub-01_ses-3_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-002/sub-01/eeg/sub-01_ses-1_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-002/sub-01/eeg/sub-01_ses-4_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-002/sub-01/eeg/sub-01_ses-5_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-003/sub-02/eeg/sub-02_ses-1_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-003/sub-02/eeg/sub-02_ses-11_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-003/sub-01/eeg/sub-01_ses-11_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-003/sub-01/eeg/sub-01_ses-2_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-01-20260605T131512Z-3-003/sub-01/eeg/sub-01_ses-10_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-002/sub-02/eeg/sub-02_ses-7_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-002/sub-02/eeg/sub-02_ses-3_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-002/sub-02/eeg/sub-02_ses-6_task-BreathCounting_eeg.bdf
# /kaggle/input/datasets/jvkrishwanth/mwdataset/sub-02-20260605T131514Z-3-002/sub-02/eeg/sub-02_ses-2_task-BreathCounting_eeg.bdf

# %%
"""Reproduce the reference band-power trajectories for MWDataset's 64 EEG channels.

The analysis uses all 64 BIDS EEG channels and removes ICA components correlated
with the available EXG channels before deriving Focus and MW epochs from the
MWDataset event codes.
"""

import gc
import os
from pathlib import Path
import warnings

# Avoid an MNE/Numba cache issue in the desktop Python installation.
os.environ.setdefault("NUMBA_DISABLE_JIT", "1")
os.environ.setdefault("MNE_NUM_JOBS", "1")

import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
import mne
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.signal import welch
from scipy.stats import norm
import statsmodels.formula.api as smf


# Kaggle paths.  Set MWDATASET_ROOT / BAND_POWER_OUTPUT_DIR only when running
# outside Kaggle (for example, on a local copy of the dataset).
DATASET_ROOT = Path(os.environ.get("MWDATASET_ROOT", "/kaggle/input/datasets/jvkrishwanth/mwdataset"))
OUTPUT_DIR = Path(os.environ.get("BAND_POWER_OUTPUT_DIR", "/kaggle/working/mwdataset_64ch_all_band_results"))
SUBJECTS = ("sub-01", "sub-02")
SESSIONS = range(1, 12)
BDF_ARCHIVES = {
    "sub-01": {1: "sub-01-20260605T131512Z-3-002", 2: "sub-01-20260605T131512Z-3-003", 3: "sub-01-20260605T131512Z-3-002", 4: "sub-01-20260605T131512Z-3-002", 5: "sub-01-20260605T131512Z-3-002", 6: "sub-01-20260605T131512Z-3-001", 7: "sub-01-20260605T131512Z-3-001", 8: "sub-01-20260605T131512Z-3-001", 9: "sub-01-20260605T131512Z-3-001", 10: "sub-01-20260605T131512Z-3-003", 11: "sub-01-20260605T131512Z-3-003"},
    "sub-02": {1: "sub-02-20260605T131514Z-3-003", 2: "sub-02-20260605T131514Z-3-002", 3: "sub-02-20260605T131514Z-3-002", 4: "sub-02-20260605T131514Z-3-001", 5: "sub-02-20260605T131514Z-3-001", 6: "sub-02-20260605T131514Z-3-002", 7: "sub-02-20260605T131514Z-3-002", 8: "sub-02-20260605T131514Z-3-001", 9: "sub-02-20260605T131514Z-3-001", 10: "sub-02-20260605T131514Z-3-001", 11: "sub-02-20260605T131514Z-3-003"},
}
METADATA_ARCHIVES = {"sub-01": "sub-01-20260605T131512Z-3-001", "sub-02": "sub-02-20260605T131514Z-3-001"}

BANDS = {"Delta": (1.0, 4.0), "Theta": (4.0, 8.0), "Alpha": (8.0, 12.0), "Beta": (13.0, 30.0), "Gamma": (30.0, 45.0)}
TARGET_SFREQ = 256.0
EPOCH_SECONDS = 4.9
WINDOW_SECONDS, STEP_SECONDS = 1.0, 0.5
EVENT_TRIAL_START, EVENT_MW_REPORT, EVENT_START_COUNTING = 10, 30, 50
FOCUS_START_OFFSET, MW_START_OFFSET = 1.0, -5.0


def session_paths(subject, session):
    label = f"ses-{session}"
    return (
        DATASET_ROOT / BDF_ARCHIVES[subject][session] / subject / "eeg" / f"{subject}_{label}_task-BreathCounting_eeg.bdf",
        DATASET_ROOT / METADATA_ARCHIVES[subject] / subject / "eeg" / f"{subject}_{label}_task-BreathCounting_channels.tsv",
    )


def deduplicate_events(events):
    if not len(events):
        return events
    frame = pd.DataFrame(events, columns=["sample", "previous", "code"])
    return frame.drop_duplicates(["sample", "code"]).sort_values(["sample", "code"])[["sample", "previous", "code"]].to_numpy(dtype=int)


def make_epoch_events(events, sfreq, last_sample, epoch_samples):
    rows = []
    for sample, _, code in events:
        if code == EVENT_MW_REPORT:
            start, state = sample + round(MW_START_OFFSET * sfreq), 1
        elif code in (EVENT_TRIAL_START, EVENT_START_COUNTING):
            start, state = sample + round(FOCUS_START_OFFSET * sfreq), 0
        else:
            continue
        if 0 <= start and start + epoch_samples <= last_sample:
            rows.append([start, 0, state])
    return deduplicate_events(np.asarray(rows, dtype=int)) if rows else np.empty((0, 3), dtype=int)


def ica_clean(raw, eeg_names, exg_names, correlation_threshold=0.30):
    """Remove ICA components correlated with EXG channels without dropping trials."""
    cleaned = raw.copy()
    if not exg_names:
        return cleaned.pick(eeg_names)
    ica = mne.preprocessing.ICA(
        n_components=0.99, method="fastica", random_state=42, max_iter="auto",
    )
    ica.fit(cleaned, picks=eeg_names, verbose=False)
    scores = [
        np.asarray(ica.score_sources(cleaned, target=cleaned.get_data(picks=[name])[0]), dtype=float)
        for name in exg_names
    ]
    excluded = np.flatnonzero(np.max(np.abs(np.vstack(scores)), axis=0) >= correlation_threshold)
    ica.apply(cleaned, exclude=excluded, verbose=False)
    return cleaned.pick(eeg_names)

def extract_windows():
    rows = []
    for subject in SUBJECTS:
        for session in SESSIONS:
            bdf_path, channels_path = session_paths(subject, session)
            print(f"Reading {subject}, session {session}", flush=True)
            raw = mne.io.read_raw_bdf(bdf_path, preload=False, stim_channel="Status", verbose=False)
            events = mne.find_events(raw, stim_channel="Status", shortest_event=1, consecutive=True, verbose=False)
            channel_table = pd.read_csv(channels_path, sep="\t")
            eeg_names = channel_table.loc[channel_table["channelTypes"].fillna("").str.upper().eq("EEG"), "name"].astype(str).tolist()
            eeg_names = [name for name in eeg_names if name in raw.ch_names]
            if len(eeg_names) != 64:
                raise RuntimeError(f"{subject} session {session}: expected 64 EEG channels, found {len(eeg_names)}.")
            exg_names = [f"EXG{i}" for i in range(1, 9) if f"EXG{i}" in raw.ch_names]
            original_sfreq = raw.info["sfreq"]
            raw.pick(eeg_names + exg_names).load_data()
            raw.resample(TARGET_SFREQ, npad="auto", verbose=False)
            events[:, 0] = np.rint(events[:, 0] * TARGET_SFREQ / original_sfreq).astype(int)
            events = deduplicate_events(events)
            raw.filter(0.5, 45.0, fir_design="firwin", verbose=False)
            raw = ica_clean(raw, eeg_names, exg_names)
            epoch_samples = round(EPOCH_SECONDS * raw.info["sfreq"])
            epoch_events = make_epoch_events(events, raw.info["sfreq"], raw.n_times - 1, epoch_samples)
            epochs = mne.Epochs(raw, epoch_events, event_id={"Focus": 0, "MW": 1}, tmin=0, tmax=EPOCH_SECONDS - 1 / raw.info["sfreq"], baseline=None, reject=None, flat=None, preload=True, event_repeated="drop", verbose=False)
            window_n, step_n = round(WINDOW_SECONDS * raw.info["sfreq"]), round(STEP_SECONDS * raw.info["sfreq"])
            for epoch_index, (epoch, event) in enumerate(zip(epochs.get_data(), epochs.events)):
                state = "MW" if event[2] == 1 else "Focus"
                for window_index, start in enumerate(range(0, epoch.shape[-1] - window_n + 1, step_n)):
                    freqs, psd = welch(epoch[:, start:start + window_n], fs=raw.info["sfreq"], nperseg=window_n, axis=-1)
                    row = {"Subject": subject, "Session": session, "Epoch": f"{subject}_{session}_{epoch_index}", "State": state, "Epoch_Index": epoch_index, "Window_Index": window_index, "Time_s": (start + window_n / 2) / raw.info["sfreq"], "N_EEG_Channels": len(eeg_names)}
                    for band, (low, high) in BANDS.items():
                        mask = (freqs >= low) & (freqs < high)
                        # Mean is explicitly across frequency bins and all 64 EEG channels.
                        row[f"Log10_{band}_Power"] = np.log10(psd[:, mask].mean() + 1e-20)
                    rows.append(row)
            del epochs, raw
            gc.collect()
    if not rows:
        raise RuntimeError("No valid MWDataset epochs were extracted.")
    return pd.DataFrame(rows)


def epoch_summaries(windows, band):
    value = f"Log10_{band}_Power"
    rows = []
    for (subject, epoch, state), part in windows.groupby(["Subject", "Epoch", "State"], observed=True):
        row = {"Subject": subject, "Epoch": epoch, "State": state, "Mean_log10_power": part[value].mean(), "N_Windows": len(part)}
        row["Slope_log10_power_per_second"] = np.polyfit(part.Time_s, part[value], 1)[0] if len(part) >= 3 else np.nan
        rows.append(row)
    return pd.DataFrame(rows)


def contrast_result(fit, contrast, band, analysis):
    params, cov = fit.params, fit.cov_params().loc[fit.params.index, fit.params.index]
    estimate = float(contrast @ params.to_numpy()); se = float(np.sqrt(contrast @ cov.to_numpy() @ contrast)); z = estimate / se
    p_value = 2 * norm.sf(abs(z))
    return {"Band": band, "Analysis": analysis, "Estimate": estimate, "SE": se, "z": z, "CI_95_low": estimate - 1.96 * se, "CI_95_high": estimate + 1.96 * se, "p_value": p_value}


def analyse_band(windows, band):
    summary = epoch_summaries(windows, band); summary["State"] = pd.Categorical(summary.State, categories=["Focus", "MW"])
    mean_fit = smf.ols("Mean_log10_power ~ C(State, Treatment(reference='Focus'))", summary).fit(cov_type="cluster", cov_kwds={"groups": summary.Subject})
    mean_names = list(mean_fit.params.index); state_name = next(n for n in mean_names if n.startswith("C(State,")); mean_contrast = np.zeros(len(mean_names)); mean_contrast[mean_names.index(state_name)] = 1
    trend = summary.dropna(subset=["Slope_log10_power_per_second"])
    trend_fit = smf.ols("Slope_log10_power_per_second ~ C(State, Treatment(reference='Focus'))", trend).fit(cov_type="cluster", cov_kwds={"groups": trend.Subject})
    trend_names = list(trend_fit.params.index); trend_state = next(n for n in trend_names if n.startswith("C(State,")); focus = np.zeros(len(trend_names)); focus[trend_names.index("Intercept")] = 1; mw = focus.copy(); mw[trend_names.index(trend_state)] = 1
    return summary, [contrast_result(mean_fit, mean_contrast, band, "MW minus Focus mean power"), contrast_result(trend_fit, focus, band, "Focus change over time"), contrast_result(trend_fit, mw, band, "MW change over time")]


def plot_band(windows, band):
    value = f"Log10_{band}_Power"; subject_curve = windows.groupby(["Subject", "State", "Time_s"], as_index=False)[value].mean()
    stats = subject_curve.groupby(["State", "Time_s"], as_index=False)[value].agg(mean="mean", sem="sem")
    fig, ax = plt.subplots(figsize=(9, 5.5))
    for state, colour in (("Focus", "#2878B5"), ("MW", "#D1495B")):
        series = stats[stats.State == state]; plot_time = series.Time_s + MW_START_OFFSET if state == "MW" else series.Time_s; ax.plot(plot_time, series["mean"], marker="o", lw=2.5, label=state, color=colour); ax.fill_between(plot_time, series["mean"] - series["sem"], series["mean"] + series["sem"], color=colour, alpha=.2)
    ax.set(title=f"{band}-band power over time", xlabel="Time (s)", ylabel=f"Mean log10 {band.lower()} PSD (power/Hz)"); ax.legend(title="State"); fig.tight_layout(); fig.savefig(OUTPUT_DIR / f"{band.lower()}_band_power_over_time.png", dpi=200); plt.close(fig)
    return subject_curve


def plot_all_bands(curves):
    fig, axes = plt.subplots(1, 2, figsize=(15, 5.5), sharey=True)
    colours = {"Delta": "#4C78A8", "Theta": "#F58518", "Alpha": "#54A24B", "Beta": "#E45756", "Gamma": "#B279A2"}
    for ax, state in zip(axes, ("Focus", "MW")):
        for band, curve in curves.items():
            value = f"Log10_{band}_Power"; part = curve[curve.State == state]; z = (part[value] - curve[value].mean()) / curve[value].std(ddof=0); summary = pd.DataFrame({"Time_s": part.Time_s, "z": z}).groupby("Time_s").z.agg(["mean", "sem"]).reset_index()
            plot_time = summary.Time_s + MW_START_OFFSET if state == "MW" else summary.Time_s; ax.plot(plot_time, summary["mean"], marker="o", lw=2, label=band, color=colours[band]); ax.fill_between(plot_time, summary["mean"] - summary["sem"], summary["mean"] + summary["sem"], color=colours[band], alpha=.12)
        ax.axhline(0, color="black", lw=.8); ax.set(title=state, xlabel="Time relative to button press (s)" if state == "MW" else "Time within epoch (s)")
    axes[0].set_ylabel("Standardised mean log10 PSD (z)"); axes[1].legend(title="Band", bbox_to_anchor=(1.02, 1), loc="upper left"); fig.suptitle("All EEG bands: power trajectories", y=1.02); fig.tight_layout(); fig.savefig(OUTPUT_DIR / "all_bands_power_over_time_standardised.png", dpi=200, bbox_inches="tight"); plt.close(fig)


def main():
    warnings.filterwarnings("ignore"); mne.set_log_level("WARNING"); sns.set_theme(style="whitegrid", context="talk"); OUTPUT_DIR.mkdir(exist_ok=True)
    windows = extract_windows(); windows.to_csv(OUTPUT_DIR / "all_band_window_level_data.csv", index=False)
    all_results, curves = [], {}
    for band in BANDS:
        summary, results = analyse_band(windows, band); summary.to_csv(OUTPUT_DIR / f"{band.lower()}_epoch_summaries.csv", index=False); all_results.extend(results); curves[band] = plot_band(windows, band)
        results = pd.DataFrame(all_results)
    results["Statistical_decision_alpha_0.05"] = np.where(
        results["p_value"] < 0.05, "Statistically significant", "Not statistically significant"
    )
    results.to_csv(OUTPUT_DIR / "all_band_statistical_results.csv", index=False)
    plot_all_bands(curves)
    print("\nStatistical results:\n", results.to_string(index=False))
    significant_results = results.loc[results["p_value"] < 0.05].sort_values("p_value").copy()
    print("\nAll statistically significant results (p < 0.05):\n", significant_results.to_string(index=False))
    remaining_results = results.loc[results["p_value"] >= 0.05].nsmallest(5, "p_value")
    print("\nFive lowest p-value results among the remaining analyses:\n", remaining_results.to_string(index=False))
    print(f"\nSaved 64-channel plots and CSVs to {OUTPUT_DIR}")

if __name__ == "__main__":
    main()
# Out:
# Reading sub-01, session 1
# Reading sub-01, session 2
# Reading sub-01, session 3
# Reading sub-01, session 4
# Reading sub-01, session 5
# Reading sub-01, session 6
# Reading sub-01, session 7
# Reading sub-01, session 8
# Reading sub-01, session 9
# Reading sub-01, session 10
# Reading sub-01, session 11
# Reading sub-02, session 1
# Reading sub-02, session 2
# Reading sub-02, session 3
# Reading sub-02, session 4
# Reading sub-02, session 5
# Reading sub-02, session 6
# Reading sub-02, session 7
# Reading sub-02, session 8
# Reading sub-02, session 9
# Reading sub-02, session 10
# Reading sub-02, session 11
#
# Statistical results:
#   Band                  Analysis  Estimate       SE         z  CI_95_low  CI_95_high      p_value Statistical_decision_alpha_0.05
# Delta MW minus Focus mean power  0.071791 0.044818  1.601820  -0.016053    0.159634 1.091954e-01   Not statistically significant
# Delta    Focus change over time  0.003119 0.004326  0.720985  -0.005360    0.011597 4.709186e-01   Not statistically significant
# Delta       MW change over time  0.008208 0.004607  1.781667  -0.000822    0.017238 7.480350e-02   Not statistically significant
# Theta MW minus Focus mean power  0.045644 0.003085 14.793747   0.039596    0.051691 1.607504e-49       Statistically significant
# Theta    Focus change over time  0.001711 0.002862  0.597801  -0.003899    0.007321 5.499725e-01   Not statistically significant
# Theta       MW change over time  0.001813 0.001785  1.016050  -0.001685    0.005311 3.096058e-01   Not statistically significant
# Alpha MW minus Focus mean power  0.142912 0.060167  2.375266   0.024985    0.260838 1.753630e-02       Statistically significant
# Alpha    Focus change over time  0.002742 0.004448  0.616432  -0.005977    0.011461 5.376092e-01   Not statistically significant
# Alpha       MW change over time  0.001694 0.003331  0.508538  -0.004835    0.008223 6.110758e-01   Not statistically significant
#  Beta MW minus Focus mean power  0.014992 0.006536  2.293842   0.002182    0.027802 2.179956e-02       Statistically significant
#  Beta    Focus change over time -0.009567 0.001172 -8.164971  -0.011864   -0.007271 3.215132e-16       Statistically significant
#  Beta       MW change over time  0.000682 0.001537  0.443516  -0.002331    0.003694 6.573923e-01   Not statistically significant
# Gamma MW minus Focus mean power -0.018484 0.013889 -1.330821  -0.045706    0.008739 1.832480e-01   Not statistically significant
# Gamma    Focus change over time -0.004687 0.001847 -2.538232  -0.008306   -0.001068 1.114140e-02       Statistically significant
# Gamma       MW change over time  0.001531 0.001075  1.423648  -0.000577    0.003639 1.545483e-01   Not statistically significant
#
# All statistically significant results (p < 0.05):
#   Band                  Analysis  Estimate       SE         z  CI_95_low  CI_95_high      p_value Statistical_decision_alpha_0.05
# Theta MW minus Focus mean power  0.045644 0.003085 14.793747   0.039596    0.051691 1.607504e-49       Statistically significant
#  Beta    Focus change over time -0.009567 0.001172 -8.164971  -0.011864   -0.007271 3.215132e-16       Statistically significant
# Gamma    Focus change over time -0.004687 0.001847 -2.538232  -0.008306   -0.001068 1.114140e-02       Statistically significant
# Alpha MW minus Focus mean power  0.142912 0.060167  2.375266   0.024985    0.260838 1.753630e-02       Statistically significant
#  Beta MW minus Focus mean power  0.014992 0.006536  2.293842   0.002182    0.027802 2.179956e-02       Statistically significant
#
# Five lowest p-value results among the remaining analyses:
#   Band                  Analysis  Estimate       SE         z  CI_95_low  CI_95_high  p_value Statistical_decision_alpha_0.05
# Delta       MW change over time  0.008208 0.004607  1.781667  -0.000822    0.017238 0.074803   Not statistically significant
# Delta MW minus Focus mean power  0.071791 0.044818  1.601820  -0.016053    0.159634 0.109195   Not statistically significant
# Gamma       MW change over time  0.001531 0.001075  1.423648  -0.000577    0.003639 0.154548   Not statistically significant
# Gamma MW minus Focus mean power -0.018484 0.013889 -1.330821  -0.045706    0.008739 0.183248   Not statistically significant
# Theta       MW change over time  0.001813 0.001785  1.016050  -0.001685    0.005311 0.309606   Not statistically significant
#
# Saved 64-channel plots and CSVs to /kaggle/working/mwdataset_64ch_all_band_results
